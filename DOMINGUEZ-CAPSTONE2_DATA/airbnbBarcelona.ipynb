# %%
import os 
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_rows', 1000)

# %%
df = pd.read_csv('calendar.csv')

# %%
df
# Out:
#          listing_id        date available    price adjusted_price  \
# 0            513825  2020-05-11         f  $150.00        $135.00
# 1            515230  2020-05-12         f   $44.00         $44.00
# 2            515230  2020-05-13         f   $44.00         $44.00
# 3            515230  2020-05-14         f   $44.00         $44.00
# 4            515230  2020-05-15         f   $44.00         $44.00
# ...             ...         ...       ...      ...            ...
# 7614002    43255379  2021-05-07         f   $67.00         $67.00
# 7614003    43255379  2021-05-08         f   $67.00         $67.00
# 7614004    43255379  2021-05-09         f   $67.00         $67.00
# 7614005    43255379  2021-05-10         f   $67.00         $67.00
# 7614006    43255379  2021-05-11         f   $67.00         $67.00
#
#          minimum_nights  maximum_nights
# 0                   2.0           365.0
# 1                  90.0          1125.0
# 2                  90.0          1125.0
# ...

# %%
df2 = pd.read_csv('listings.csv')

# %%
c = df2[['id','host_id', 'neighbourhood_group','neighbourhood', 'latitude', 'longitude', 
        'room_type', 'price', 'calculated_host_listings_count', 'availability_365']]
c = c[c['room_type'] != 'Hotel room']
mask1 = c['calculated_host_listings_count'] > 1
c['host_id'].value_counts()
# Out:
# 170716140    173
# 4459553      155
# 102947901    137
# 1447144      132
# 193618270    126
#             ...
# 3014342        1
# 71417359       1
# 22845131       1
# 25546448       1
# 243730433      1
# Name: host_id, Length: 10089, dtype: int64

# %%
nohotel = df2[df2['room_type'] != 'Hotel room']
nohotel.groupby('host_id').filter(lambda x: len(x)>1).sort_values('host_id')
# Out:
#              id                                               name    host_id  \
# 13064  33009250         Boutique apartment in Eixample City Centre      10704
# 19087  42062992  4-bedroom with terrace near Pg Gracia&Pl Catal...      10704
# 5414   15406272            Gorgeous 3 bedroom apartment - Gran Via      10704
# 3443    8181779                 Sagrada Familia / Sant Pau - 4 hab      10704
# 3450    8215059                         Park Guell - 1bdr / 1 bath      10704
# ...         ...                                                ...        ...
# 20738  43339844                       Spectacular unique view room  345174698
# 20758  43341059                     whole BCN City & Sea view room  345174698
# 20840  43385770                               HABITACIÓN EN GRÀCIA  345349909
# 20841  43385885                               HABITACIÓN EN GRÀCIA  345349909
# 20844  43386174                               HABITACIÓN EN GRÀCIA  345349909
#
# ...

# %%
y = nohotel.groupby('host_id').count()

# %%
df2['room_type'].value_counts()
# Out:
# Private room       10610
# Entire home/apt     9554
# Hotel room           454
# Shared room          240
# Name: room_type, dtype: int64

# %%
df2.head()
# Out:
#       id                                             name  host_id  \
# 0  21974               Comf. double room/private bathroom    73163
# 1  23197  Forum DeLuxe 5 mins Walk  To CCIB Center & Sea★    90417
# 2  31958                  Gaudi Attic 1, Friendly Rentals   136853
# 3  32471                  Gaudi Attic 2, Friendly Rentals   136853
# 4  32711                 Sagrada Familia area - Còrsega 1   135703
#
#         host_name neighbourhood_group                       neighbourhood  \
# 0          Andres        Ciutat Vella                      el Barri Gòtic
# 1  Etain (Marnie)          Sant Martí               el Besòs i el Maresme
# 2         Fidelio              Gràcia  el Camp d'en Grassot i Gràcia Nova
# 3         Fidelio              Gràcia  el Camp d'en Grassot i Gràcia Nova
# 4            Nick              Gràcia  el Camp d'en Grassot i Gràcia Nova
#
#    latitude  longitude        room_type  price  minimum_nights  \
# ...

# %%
roomtype = df2.groupby('room_type')
roomtype.median()
# Out:
#                          id      host_id   latitude  longitude  price  \
# room_type
# Entire home/apt  24646950.5   32037490.0  41.389365   2.168380   95.5
# Hotel room       28104078.5  140571125.0  41.391050   2.165785  178.5
# Private room     28269343.5   90771808.0  41.387715   2.168460   40.0
# Shared room      32326145.5   83596890.5  41.390530   2.165920   35.0
#
#                  minimum_nights  number_of_reviews  reviews_per_month  \
# room_type
# Entire home/apt             3.0                6.0               0.81
# Hotel room                  1.0                4.0               0.46
# Private room                2.0                6.0               0.94
# Shared room                 1.0                1.0               0.48
#
#                  calculated_host_listings_count  availability_365
# room_type
# Entire home/apt                             8.0             266.0
# Hotel room                                 10.0             237.0
# ...

# %%
roomtype = df2.groupby('room_type')
roomtype.mean()
# Out:
#                            id       host_id   latitude  longitude       price  \
# room_type
# Entire home/apt  2.367306e+07  9.106105e+07  41.391297   2.168020  171.045740
# Hotel room       2.612567e+07  1.280681e+08  41.391396   2.166350  609.248899
# Private room     2.653445e+07  1.264594e+08  41.392526   2.167158   61.057022
# Shared room      2.841488e+07  1.438774e+08  41.392467   2.166674  134.175000
#
#                  minimum_nights  number_of_reviews  reviews_per_month  \
# room_type
# Entire home/apt       14.341951          40.052962           1.294142
# Hotel room             3.325991          22.555066           1.294913
# Private room           6.374741          30.724034           1.441771
# Shared room            2.750000          16.470833           1.161286
#
#                  calculated_host_listings_count  availability_365
# room_type
# Entire home/apt                       26.521352        239.062278
# ...

# %%
roomtype.count()
# Out:
#                     id   name  host_id  host_name  neighbourhood_group  \
# room_type
# Entire home/apt   9554   9553     9554       9554                 9554
# Hotel room         454    454      454        454                  454
# Private room     10610  10596    10610      10604                10610
# Shared room        240    240      240        240                  240
#
#                  neighbourhood  latitude  longitude  price  minimum_nights  \
# room_type
# Entire home/apt           9554      9554       9554   9554            9554
# Hotel room                 454       454        454    454             454
# Private room             10610     10610      10610  10610           10610
# Shared room                240       240        240    240             240
#
#                  number_of_reviews  last_review  reviews_per_month  \
# room_type
# Entire home/apt               9554         7024               7024
# ...

# %%
# Out:
#         listing_id        date
# 0            21974  2017-05-16
# 1            21974  2017-11-06
# 2            23197  2011-03-15
# 3            23197  2012-01-11
# 4            23197  2015-07-27
# ...            ...         ...
# 722836    42928170  2020-03-31
# 722837    42993509  2020-03-25
# 722838    43046105  2020-04-09
# 722839    43256894  2020-05-03
# 722840    43292767  2020-05-02
#
# [722841 rows x 2 columns]

# %%
df3
# Out:
#         listing_id        date
# 0            21974  2017-05-16
# 1            21974  2017-11-06
# 2            23197  2011-03-15
# 3            23197  2012-01-11
# 4            23197  2015-07-27
# ...            ...         ...
# 722836    42928170  2020-03-31
# 722837    42993509  2020-03-25
# 722838    43046105  2020-04-09
# 722839    43256894  2020-05-03
# 722840    43292767  2020-05-02
#
# [722841 rows x 2 columns]

# %%
df4 = pd.read_csv('neighbourhoods.csv')

# %%
df4
# Out:
#     neighbourhood_group                          neighbourhood
# 0          Ciutat Vella                         el Barri Gòtic
# 1          Ciutat Vella                               el Raval
# 2          Ciutat Vella                         la Barceloneta
# 3          Ciutat Vella  Sant Pere, Santa Caterina i la Ribera
# 4              Eixample                          el Fort Pienc
# ..                  ...                                    ...
# 68  Sarrià-Sant Gervasi                        les Tres Torres
# 69  Sarrià-Sant Gervasi                 Sant Gervasi - Galvany
# 70  Sarrià-Sant Gervasi             Sant Gervasi - la Bonanova
# 71  Sarrià-Sant Gervasi                                 Sarrià
# 72  Sarrià-Sant Gervasi  Vallvidrera, el Tibidabo i les Planes
#
# [73 rows x 2 columns]

# %%
df5 = pd.read_csv('neighbourhoods.geojson')

# %%
df5
# Out:
# Empty DataFrame
# ...

# %%
neighborhood = df2.groupby('neighbourhood_group')
neighborhood.mean()
# Out:
#                                id       host_id   latitude  longitude  \
# neighbourhood_group
# Ciutat Vella         2.804128e+07  1.315737e+08  41.382107   2.176120
# Eixample             2.416231e+07  1.028914e+08  41.391222   2.165196
# Gràcia               2.285964e+07  9.331230e+07  41.404570   2.157835
# Horta-Guinardó       2.600283e+07  1.094067e+08  41.419548   2.163845
# Les Corts            2.452776e+07  1.074398e+08  41.383055   2.129380
# Nou Barris           2.799940e+07  1.364590e+08  41.437562   2.175453
# Sant Andreu          2.616068e+07  1.213057e+08  41.426907   2.187695
# Sant Martí           2.475775e+07  1.078887e+08  41.405361   2.197723
# Sants-Montjuïc       2.440352e+07  1.037270e+08  41.373309   2.150125
# Sarrià-Sant Gervasi  2.468125e+07  1.001277e+08  41.402003   2.140869
#
#                           price  minimum_nights  number_of_reviews  \
# neighbourhood_group
# Ciutat Vella          92.530608       14.153242          27.847966
# ...

# %%
neighborhood = df2.groupby(['neighbourhood_group','room_type'])
neighborhood.median()
# Out:
#                                              id      host_id   latitude  \
# neighbourhood_group room_type
# Ciutat Vella        Entire home/apt  31274357.0  102947901.0  41.381880
#                     Hotel room       29115513.0  168877958.0  41.382960
#                     Private room     31030467.0  128880524.0  41.381570
#                     Shared room      34104982.5  223030082.0  41.383635
# Eixample            Entire home/apt  22238345.0   23226762.0  41.391920
#                     Hotel room       27670540.5   98330509.0  41.391050
#                     Private room     28483229.0   80847129.0  41.389930
#                     Shared room      31918666.0  123717342.0  41.391620
# Gràcia              Entire home/apt  21315883.0   11573686.5  41.402910
#                     Hotel room       32931254.5  238804510.5  41.404560
#                     Private room     25039203.5   53065378.0  41.405105
#                     Shared room      34650784.0   95048348.0  41.399410
# ...

# %%
neighborhood = df2.groupby(['neighbourhood_group','neighbourhood'])
neighborhood[['price']].mean().head(100)
# Out:
#                                                                        price
# neighbourhood_group neighbourhood
# Ciutat Vella        Sant Pere, Santa Caterina i la Ribera          96.820685
#                     el Barri Gòtic                                111.905674
#                     el Raval                                       76.386443
#                     la Barceloneta                                 81.790123
# Eixample            Sant Antoni                                   236.876298
#                     el Fort Pienc                                  91.213793
#                     l'Antiga Esquerra de l'Eixample               174.792606
#                     la Dreta de l'Eixample                        231.313917
#                     la Nova Esquerra de l'Eixample                 85.541442
#                     la Sagrada Família                            100.136405
# Gràcia              Vallcarca i els Penitents                     173.161538
# ...

# %%
df2.groupby('neighbourhood_group')['price'].mean()
# Out:
# neighbourhood_group
# Ciutat Vella            92.530608
# Eixample               171.782312
# Gràcia                 109.331451
# Horta-Guinardó          59.789165
# Les Corts              100.407895
# Nou Barris              45.689286
# Sant Andreu             53.002874
# Sant Martí             131.744371
# Sants-Montjuïc          98.377288
# Sarrià-Sant Gervasi    120.090446
# Name: price, dtype: float64

# %%
df2.groupby('neighbourhood_group')['price'].median()
# Out:
# neighbourhood_group
# Ciutat Vella           55
# Eixample               73
# Gràcia                 60
# Horta-Guinardó         39
# Les Corts              50
# Nou Barris             30
# Sant Andreu            35
# Sant Martí             55
# Sants-Montjuïc         55
# Sarrià-Sant Gervasi    75
# Name: price, dtype: int64

# %%
ax = sns.barplot(x = 'room_type', y = 'price', data = gotic, hue = 'room_type', ci = False)

# %%
mask = nohotel['neighbourhood'] == ('el Barri Gòtic')
gotic = nohotel[mask]
gotic
# Out:
#              id                                               name    host_id  \
# 0         21974                 Comf. double room/private bathroom      73163
# 5         34241                   Private Double room - Plaza Real      73163
# 6         34981               VIDRE HOME PLAZA REAL on LAS RAMBLAS      73163
# 19        68547               two beds with private shower 30% off     340570
# 47       110098                        023. Gignàs Gótic Apartment     396363
# ...         ...                                                ...        ...
# 20815  43369165             Beautiful Room in gothic with AC *****  266657277
# 20829  43376775  Studio apartment Blue right in the Gothic quarter    9478280
# 20831  43378593                        Bedroom "A" Kosmo Apartment    9916442
# 20835  43380653                        Bedroom "B" Kosmo Apartment    9916442
# 20837  43384519  Studio apartment Green right in the Gothic qua...    9478280
#
# ...

# %%
nohotel.hist(column='calculated_host_listings_count', grid=False, bins=50, figsize=[15,6])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1e823dd0>]],
#       dtype=object)

# %%
df2[['calculated_host_listings_count']]>1
# Out:
#        calculated_host_listings_count
# 0                                True
# 1                                True
# 2                                True
# 3                                True
# 4                                True
# ...                               ...
# 20853                            True
# 20854                            True
# 20855                           False
# 20856                           False
# 20857                           False
#
# [20858 rows x 1 columns]

# %%
y.hist(column='id', grid=False, bins=100, figsize=[15,6])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a25e94b50>]],
#       dtype=object)

# %%
x = goticgroup.count()

# %%
goticgroup = gotic.groupby('host_id')
goticgroup.filter(lambda x: len(x)>1).sort_values('host_id')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-200-c2e18a356c48> in <module>
#       1 goticgroup = gotic.groupby('host_id')
# ----> 2 df2.filter(lambda x: len(x)>1).sort_values('host_id')
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in filter(self, items, like, regex, axis)
#    4697         if items is not None:
#    4698             name = self._get_axis_name(axis)
# -> 4699             return self.reindex(**{name: [r for r in items if r in labels]})
#    4700         elif like:
#    4701
#
# TypeError: 'function' object is not iterable

# %%
total_listings = df2.groupby('host_id')[['id']].count()
results = pd.merge(df2, total_listings, on = ['host_id'])
results.sort_values('host_id').
# Out:
#           id_x                                        name  host_id  \
# 5053   6287375  Single & Quite Room in Guinardó, Barcelona     3073
# 1550  19922686               SF11 - Sagrada Familia - 1hab    10704
# 1544   8260935           D3 - Centro Ciudad / Pº de Gracia    10704
# 1551  20855659       Born beach side two bedroom apartment    10704
# 1545   8261391                 Independent Study in Gracia    10704
#
#       host_name neighbourhood_group                          neighbourhood  \
# 5053     Ricard      Horta-Guinardó                            el Guinardó
# 1550  Weflating            Eixample                     la Sagrada Família
# 1544  Weflating            Eixample                 la Dreta de l'Eixample
# 1551  Weflating        Ciutat Vella  Sant Pere, Santa Caterina i la Ribera
# 1545  Weflating              Gràcia     el Camp d'en Grassot i Gràcia Nova
#
#       latitude  longitude        room_type  price  minimum_nights  \
# ...

# %%
total_listings.id.value_counts().plot.bar()

# %%
goticgroup['price'].agg(np.mean).head()100
# Out:
# host_id  id
# 10704    8261477     130
# 34580    978990       59
# 71615    35104102     63
# 73163    21974        60
#          34241       100
#          34981       227
# 340570   68547        49
# 388382   848081       75
# 396363   110098       84
#          43022057     38
#          43022071     57
#          43068069     57
#          43068077     57
#          43068081     44
#          43068084     38
#          43068092     38
#          43068095     57
#          43068098     44
#          43068103     38
#          43068125     57
# 480528   26809311     88
#          42134091     75
# 490987   19540009    100
# 529756   41802108    152
# 620454   142121       44
#          28969462     28
#          41161174     14
# 750820   22648214     50
# 784341   164456       70
#          184516       70
# 804332   36545124     83
# 898538   5101338      70
# 952946   34588413    400
# 992682   41401117     75
#          42398172     45
# 1142511  32417958     31
# ...

# %%
# Out:
# 10142
